# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ### Analysis and Visualizing WeRateDogs Twitter archive

# %% [markdown]
# #### Steps Involved in this Project
#
# 1. Gathering Data
# 2. Accessing Data
# 3. Cleaning Data
# 4. Storing Cleaned Data
# 5. Analyzing and Visualizing Data

# %% [markdown]
# #### Analyzing and Visualizing Data for this project
# stored the clean Data in a CSV file twitter_archive_master.csv. Imported the cleaned Dataset.
#
# ![P1.png](attachment:P1.png)

# %% [markdown]
# ### Plot of Retweet of dogs overtime.
#
# ![p2.png](attachment:p2.png)

# %% [markdown]
# Over the time period of the tweets collected for this dataset, tweets decreased sharply starting in early 2016. While the tweets continue to decline over time, there are spikes i activity during the ealry spring of 2016, mid summer of 2016, but continues to decrease from there. This data set did not provide corresponding data that could provide a reason for the sharp decrease in 2016, and steady decrease from there. The owner of the WeRateDogs Twitter account should be aware of this trend, and consider ways to increase user traffic on th page.

# %% [markdown]
# #### Plot of Most popuplar dogs
#
# ![p3.png](attachment:p3.png)

# %% [markdown]
# In the above plot we see that the most common names given to dogs is Charlie with(11), names Lucy, Olivier, Cooper cloed to (10), Daisy make the (7).

# %% [markdown]
# #### Plot of correlation between Favorite and Retweet
#
# ![p4.png](attachment:p4.png)

# %% [markdown]
# With a corr of 0.79156198764899958, this shows a positive correlation between favorited/liked tweet count and retweeted tweet count. This makes sense because if you favorited or liked a tweet, you are around 70% likely to also retweet the particular tweet.
# How to correlate well to get high growth rate of twitter followers?
#
# Check the correlation between the follwers count and retweets. This shows a negative correlation with -0.3101659549893. one would think if a twitter account has 10,000 followers, the twitter handle has a more likelihood of having their tweet retweeted than a twitter account with just 5000 followers has a more chances of having their tweets retweeted.
